# %%
a= 1
b= 1

import math
def add(c,d):
    return c+d
def subtract(c,d):
    return c-d
def multiply(c,d):
    return c*d
def division(c,d):
    return c/d
def power(c,d):
    return math.pow(c,d)

g= 0

while a!=0 or b!=0:
    #a= int(input("enter the number: "))
    #b= int(input("enter the number: "))
    if g==0:
        a= int(input("enter the number: "))
        b= int(input("enter the number: "))

        if len(str(a))<=9 and len(str(b))<=9:
            print("the number according to rules")
            c=a
            d=b
        else:
            print("give the number again")
            c= int(input("enter the number: "))
            d= int(input("enter the number: "))
    else:
        b= int(input("enter the number: "))

        if len(str(b))<=9:
            print("the number according to rules")
            d=b
        else:
            print("give the number again")
            d= int(input("enter the number: "))

    print("the operation is:\n"
         "1. Addition\n"
         "2. subtraction\n"
         "3. multiplication\n"
         "4. division\n"
         "5. power\n")
    
    selection= input("enter the select between 1 to 5: ")
            
    if selection== "1":
        if g==0:
            g= g+sum(c,d)
        else:
            c=g
            g= sum(g,d)
    elif selection=="2":
        if g==0:
            g= g+ subtract(c,d)
        else:
            c=g
            g= subtract(g,d)
    elif selection=="3":
        if g==0:
            g= g+ multiply(c,d)
        else:
            c=g
            g= multiply(g,d)

    elif selection== "4":
        if g==0:
            g= g+ division(c,d)
        else:
            c=g
            g= division(g,d)
    else:
        if g==0:
            g= g+ power(c,d)
        else:
            c=g
            g= power(g,d)

    print("the answer of operation is: ",g)
    
    print("if the next int option is zero program will stop else insert 1 to continue")
    con= int(input("enter the stop or continue condition"))
    if con==0:
        break
    else:
        continue
# Out:
# enter the number: 7
# enter the number: 8
# the number according to rules
# the operation is:
# 1. Addition
# 2. subtraction
# 3. multiplication
# 4. division
# 5. power
#
# enter the select between 1 to 5: 3
# the answer of operation is:  56
# if the next int option is zero program will stop else insert 1 to continue
# enter the stop or continue condition1
# enter the number: 3
# the number according to rules
# the operation is:
# 1. Addition
# 2. subtraction
# 3. multiplication
# 4. division
# 5. power
#
# enter the select between 1 to 5: 5
# the answer of operation is:  175616.0
# if the next int option is zero program will stop else insert 1 to continue
# enter the stop or continue condition0
